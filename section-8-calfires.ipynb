# %%
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Read in data EJ data

fp = os.path.join("data","EJI_2024_California", "EJI_2024_California.gdb")

ej = gpd.read_file(fp)

# %%
# Read in palisades and eaton data 
fp_eaton = os.path.join('data','Eaton_Perimeter_20250121','Eaton_Perimeter_20250121.shp')
eaton = gpd.read_file(fp_eaton)

fp_pal = os.path.join('data','Palisades_Perimeter_20250121','Palisades_Perimeter_20250121.shp')
palisades = gpd.read_file(fp_pal)

# %%
# Check the crs of each data 
eaton.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
palisades.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
palisades.head()
# Out:
#    OBJECTID            type    Shape__Are   Shape__Len  \
# 0         1  Heat Perimeter   1182.082031   267.101144
# 1         2  Heat Perimeter   2222.488281   185.498783
# 2         3  Heat Perimeter     21.011719    22.412814
# 3         4  Heat Perimeter    214.992188    76.639180
# 4         5  Heat Perimeter  44203.453125  1569.259764
#
#                                             geometry
# 0  POLYGON ((-13193543.302 4032913.077, -13193543...
# 1  POLYGON ((-13193524.155 4033067.953, -13193524...
# 2  POLYGON ((-13193598.085 4033158.222, -13193598...
# 3  POLYGON ((-13193654.249 4033146.033, -13193656...
# 4  POLYGON ((-13194209.580 4033236.320, -13194209...

# %%
eaton.head()
# Out:
#    OBJECTID            type    Shape__Are  Shape__Len  \
# 0         1  Heat Perimeter   2206.265625  270.199719
# 1         2  Heat Perimeter  20710.207031  839.204218
# 2         3  Heat Perimeter   3639.238281  250.304502
# 3         4  Heat Perimeter   1464.550781  148.106792
# 4         5  Heat Perimeter   4132.753906  247.960744
#
#                                             geometry
# 0  POLYGON ((-13146936.686 4051222.067, -13146932...
# 1  POLYGON ((-13150835.463 4052713.929, -13150831...
# 2  POLYGON ((-13153094.697 4053057.596, -13153113...
# 3  POLYGON ((-13145097.740 4053118.235, -13145100...
# 4  POLYGON ((-13153131.126 4053196.882, -13153131...

# %%
ej.crs
# Out:
# <Projected CRS: ESRI:102003>
# Name: USA_Contiguous_Albers_Equal_Area_Conic
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# Reproject crs of ej to Eaton's crs 
ej = ej.to_crs(crs = eaton.crs)

# %%
ej.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Spatial join to get boundaries of census tracts and perimeter 
palisades_ej = gpd.sjoin(ej, palisades, 
                         how = "inner")

# %%
# Spatial join to get boundaries of census tracts and perimeter 
eaton_ej = gpd.sjoin(ej, eaton, 
                         how = "inner")

# %%
palisades_ej.head()
# Out:
#       OBJECTID_left STATEFP COUNTYFP TRACTCE             AFFGEOID  \
# 1328           6505      06      037  262706  140000US06037262706
# 1328           6505      06      037  262706  140000US06037262706
# 1328           6505      06      037  262706  140000US06037262706
# 1328           6505      06      037  262706  140000US06037262706
# 1328           6505      06      037  262706  140000US06037262706
#
#             GEOID   GEOID_2020              COUNTY   StateDesc STATEABBR  ...  \
# 1328  06037262706  06037262706  Los Angeles County  California        CA  ...
# 1328  06037262706  06037262706  Los Angeles County  California        CA  ...
# 1328  06037262706  06037262706  Los Angeles County  California        CA  ...
# 1328  06037262706  06037262706  Los Angeles County  California        CA  ...
# 1328  06037262706  06037262706  Los Angeles County  California        CA  ...
#
#      Tribe_Names  Tribe_Flag  Shape_Length    Shape_Area  \
# ...

# %%
eaton.head()
# Out:
#    OBJECTID            type    Shape__Are  Shape__Len  \
# 0         1  Heat Perimeter   2206.265625  270.199719
# 1         2  Heat Perimeter  20710.207031  839.204218
# 2         3  Heat Perimeter   3639.238281  250.304502
# 3         4  Heat Perimeter   1464.550781  148.106792
# 4         5  Heat Perimeter   4132.753906  247.960744
#
#                                             geometry
# 0  POLYGON ((-13146936.686 4051222.067, -13146932...
# 1  POLYGON ((-13150835.463 4052713.929, -13150831...
# 2  POLYGON ((-13153094.697 4053057.596, -13153113...
# 3  POLYGON ((-13145097.740 4053118.235, -13145100...
# 4  POLYGON ((-13153131.126 4053196.882, -13153131...

# %%
fig, ax = plt.subplots()

ax.axis("off")  # Remove axis for a cleaner plot 

palisades_ej.plot( # Plot census tracts that overlap perimeter
    ax = ax
)
palisades.boundary.plot( # Plot fire perimeter boundary
    ax = ax, 
    edgecolor = "red"
)

ax.set_title('Census Tracts Overlapping Palisades Fire Perimeter')
# Out:
# Text(0.5, 1.0, 'Census Tracts Overlapping Palisades Fire Perimeter')

# %%
fig, ax = plt.subplots()

ax.axis("off") # Remove axis for a cleaner plot 

eaton_ej.plot( # Plot census tracts that overlap perimeter
    ax = ax
)
eaton.boundary.plot( # Plot fire perimeter boundary
    ax = ax, 
    edgecolor = "red"
)

ax.set_title('Census Tracts Overlapping Eaton Fire Perimeter')
# Out:
# Text(0.5, 1.0, 'Census Tracts Overlapping Eaton Fire Perimeter')
